# %%
import pandas as pd
tabel = pd.read_csv('20140221_01_01_03_250lm(notas).csv')
display(tabel)
# Out:
#            time  handwheelAngle  throttle  brake  clutch  engineSpeed   PPS  \
# 0         0.000             1.4       3.3    0.0    95.0         1662  4.97
# 1         0.001             1.4       3.3    0.0    95.0         1662  4.95
# 2         0.002             1.4       3.3    0.0    94.5         1662  4.96
# 3         0.003             1.4       3.3    0.0    94.5         1662  4.97
# 4         0.004             1.4       3.3    0.0    94.0         1662  4.97
# ...         ...             ...       ...    ...     ...          ...   ...
# 535463  535.463            -9.5       0.3    0.0     0.0            0  4.96
# 535464  535.464            -9.5       0.2    0.0     0.0            0  4.97
# 535465  535.465            -9.5       0.2    0.0     0.0            0  4.96
# 535466  535.466            -9.5       0.3    0.0     0.0            0  4.96
# 535467  535.467            -9.5       0.2    0.0     0.0            0  4.97
#
# ...

# %%
tabel2 = tabel.dropna()
tabel2.head()
# Out:
#          time  handwheelAngle  throttle  brake  clutch  engineSpeed   PPS  \
# 44510  44.510            33.9      11.8    0.0     0.0         1890  4.96
# 44511  44.511            34.0      11.9    0.0     0.0         1890  4.98
# 44512  44.512            34.0      12.0    0.0     0.0         1890  4.97
# 44513  44.513            34.1      11.9    0.0     0.0         1890  4.97
# 44514  44.514            34.1      11.9    0.0     0.0         1890  4.97
#
#         gpsTime   latitude  longitude  ...  chassisAccelRL  chassisAccelRR  \
# 44510  52203.01  26.921481 -80.305948  ...           7.564          10.094
# 44511  52203.01  26.921481 -80.305948  ...           7.701           9.015
# 44512  52203.01  26.921481 -80.305948  ...           8.966           7.642
# 44513  52203.01  26.921481 -80.305948  ...          10.163           7.191
# 44514  52203.01  26.921481 -80.305948  ...          11.213           6.229
#
# ...

# %%
tabel.describe()
# Out:
#                 time  handwheelAngle       throttle          brake  \
# count  535468.000000   535468.000000  535468.000000  535468.000000
# mean      267.733500       -6.379517       7.649887       0.313919
# std       154.576441       19.439137      13.328334       3.126117
# min         0.000000      -60.600000       0.000000       0.000000
# 25%       133.866750       -9.800000       0.300000       0.000000
# 50%       267.733500       -9.500000       0.300000       0.000000
# 75%       401.600250        0.000000       9.600000       0.000000
# max       535.467000      352.300000     100.000000     100.000000
#
#               clutch    engineSpeed            PPS        gpsTime  \
# count  535468.000000  535468.000000  535468.000000  535468.000000
# mean       17.796457    2151.542105       5.009370   52426.240997
# std        27.290444    1931.167369       1.019413     154.582875
# min         0.000000       0.000000       0.000000   52158.500000
# ...

# %%
#como a velocidade predominante é a horizontal, a maior velocidade é a que tem a maior velocidade horizontal
max(tabel.horizontalSpeed)
tabel.loc[tabel.horizontalSpeed==max(tabel.horizontalSpeed),'time']
# Out:
# 270680    270.680
# 270681    270.681
# 270682    270.682
# 270683    270.683
# 270684    270.684
# 270685    270.685
# 270686    270.686
# 270687    270.687
# 270688    270.688
# 270689    270.689
# 270700    270.700
# 270701    270.701
# 270702    270.702
# 270703    270.703
# 270704    270.704
# 270705    270.705
# 270706    270.706
# 270707    270.707
# 270708    270.708
# 270709    270.709
# Name: time, dtype: float64

# %%
#tabel.dropna()
tabel.horizontalSpeed.mean()
# Out:
# 11.646281346410987

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.lineplot(x=tabel['time'],y=tabel['latitude'])
plt.show()

# %%
sns.lineplot(x=tabel['time'],y=tabel['longitude'])
plt.show()

# %%
sns.lineplot(x=tabel['time'],y=tabel['altitude'])
plt.show()

# %%
position = tabel.loc[:,'latitude':'longitude'] #.join
#position = position.drop_duplicates()
#display(position)

# %%
#position = position.join(tabel['time'])
position.insert(0,'time',tabel['time'])
position = position.dropna()
print(position)
#print(position.info())
# Out:
#            time   latitude  longitude
# 44510    44.510  26.921481 -80.305948
# 44511    44.511  26.921481 -80.305948
# 44512    44.512  26.921481 -80.305948
# 44513    44.513  26.921481 -80.305948
# 44514    44.514  26.921481 -80.305948
# ...         ...        ...        ...
# 535463  535.463  26.921374 -80.305995
# 535464  535.464  26.921374 -80.305995
# 535465  535.465  26.921374 -80.305995
# 535466  535.466  26.921374 -80.305995
# 535467  535.467  26.921374 -80.305995
#
# [490958 rows x 3 columns]

# %%
#index_list = position.index
#print(type(index_list))
#latitude = 26.9214812
#longitude = -80.3059475
'''for n in index_list:
    if position['latitude'][n]>26.920 and  position['longitude'][n]==-80.3059475:
        print('A latitude é:',position['latitude'][n])
        print('A longitude é:',position['longitude'][n])
        print('index é:',n)'''

tabel2 = tabel.loc[(tabel['longitude']>-80.305948) & (tabel['longitude']<-80.305947) & (tabel['latitude']>26.910) & (tabel['latitude']<26.930) & (tabel['time']>100), ['time','distance']]
tabel2.to_excel('primeira_volta.xlsx',index=False)

# %%
table2 = tabel.loc[(tabel['longitude']>-80.305950) & (tabel['longitude']<-80.305946) & (tabel['latitude']>26.910) & (tabel['latitude']<26.930) & (tabel['time']>100), ['time','distance']]
table2
# Out:
#          time  distance
# 7266   119.64  1488.072
# 11636  165.28  2630.864
# 11637  165.29  2631.027
# 11638  165.30  2631.198
# 12905  178.55  2881.532
# 12906  178.56  2881.769
# 12907  178.57  2881.994
# 12908  178.58  2882.230
# 12909  178.59  2882.466
# 12910  178.60  2882.702
# 12911  178.61  2882.927
# 12912  178.62  2883.162
# 12913  178.63  2883.397
# 14576  195.55  3327.814
# 14577  195.56  3327.989
# 14578  195.57  3328.170
# 14579  195.58  3328.350
# 14914  199.10  3390.994
# 14915  199.11  3391.201
# 14916  199.13  3391.614
# 14917  199.14  3391.827
# 16464  215.34  3792.587
# 16465  215.35  3792.758
# 16466  215.36  3792.938
# 16950  220.44  3895.219
# 16951  220.45  3895.480
# 16952  220.46  3895.732
# 17576  227.01  4078.412
# 17577  227.02  4078.634
# 17578  227.03  4078.859
# 19652  249.08  4619.847
# 19653  249.09  4620.079
# 22871  282.76  5755.470
# 22872  282.77  5755.648
# 22873  282.78  5755.833

# %%
#tratando a tabela
tabel = tabel.dropna()
#tabel[['latitude','longitude']].drop_duplicates()
tabel = tabel.drop_duplicates(['latitude','longitude'])
tabel = tabel.drop(tabel.loc[:, 'numSVsTracked':'wheelAccelRR'],axis=1)
tabel = tabel.reset_index()
tabel
# Out:
#         index    time  handwheelAngle  throttle  brake  clutch  engineSpeed  \
# 0       44510   44.51            33.9      11.8    0.0     0.0         1890
# 1       44520   44.52            34.0      11.8    0.0     0.0         1890
# 2       44530   44.53            34.1      11.8    0.0     0.0         1914
# 3       44540   44.54            34.2      11.8    0.0     0.0         1914
# 4       44550   44.55            34.0      12.0    0.0     0.0         1914
# ...       ...     ...             ...       ...    ...     ...          ...
# 27012  524010  524.01            -9.4       0.2    0.0     0.0            0
# 27013  524490  524.49            -9.5       0.2    0.0     0.0            0
# 27014  524910  524.91            -9.5       0.2    0.0     0.0            0
# 27015  526380  526.38            -9.5       0.2    0.0     0.0            0
# 27016  529530  529.53            -9.5       0.2    0.0     0.0            0
#
# ...

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(tabel, title="Pandas Profiling Report")

# %%
#profile

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(12,6))

x = tabel.time
y = tabel.longitude

ax.plot(x, y, linewidth=2.0)

x_reta = [44.510,178]
y_reta = [tabel.loc[(tabel['time']==44.510),'longitude'],tabel.loc[(tabel['time']==178),'longitude']]

ax.plot(x_reta, y_reta,'--r')

plt.show()

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(12,6))

x = tabel.time
y = tabel.latitude

ax.plot(x, y, linewidth=2.0)

x_reta = [44.510,185]
y_reta = [tabel.loc[(tabel['time']==44.510),'latitude'],tabel.loc[(tabel['time']==185),'latitude']]

ax.plot(x_reta, y_reta,'--r')

plt.show()
